# %%
import pandas as pd
import numpy as np
import time

import plotly.express as px
import seaborn as sns
from matplotlib import pyplot as plt

import sys

# !{sys.executable} -m pip install duckdb-engine

# !{sys.executable} -m pip install ipython-sql

import duckdb, sqlalchemy

from sklearn.linear_model import LogisticRegression, LinearRegression

import statsmodels.api as sm

import statsmodels.formula.api as smf


# %load_ext sql

# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:memory:
# Out:
# WARNING: The directory '/Users/ashleyzeng/Library/Caches/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# Requirement already satisfied: duckdb-engine in /anaconda3/envs/info2950/lib/python3.10/site-packages (0.6.4)
# Requirement already satisfied: numpy in /anaconda3/envs/info2950/lib/python3.10/site-packages (from duckdb-engine) (1.23.3)
# Requirement already satisfied: sqlalchemy<2.0.0,>=1.3.19 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from duckdb-engine) (1.4.32)
# Requirement already satisfied: duckdb>=0.4.0 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from duckdb-engine) (0.6.0)
# Requirement already satisfied: greenlet!=0.4.17 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from sqlalchemy<2.0.0,>=1.3.19->duckdb-engine) (1.1.1)
# WARNING: The directory '/Users/ashleyzeng/Library/Caches/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
# Requirement already satisfied: ipython-sql in /anaconda3/envs/info2950/lib/python3.10/site-packages (0.4.1)
# Requirement already satisfied: ipython>=1.0 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython-sql) (8.4.0)
# Requirement already satisfied: sqlparse in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython-sql) (0.4.3)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython-sql) (1.4.32)
# Requirement already satisfied: prettytable<1 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: six in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: backcall in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: pickleshare in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (3.0.20)
# Requirement already satisfied: appnope in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.1.2)
# Requirement already satisfied: matplotlib-inline in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (2.11.2)
# Requirement already satisfied: stack-data in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (65.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from sqlalchemy>=0.6.7->ipython-sql) (1.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda3/envs/info2950/lib/python3.10/site-packages (from pexpect>4.3->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in /anaconda3/envs/info2950/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: asttokens in /anaconda3/envs/info2950/lib/python3.10/site-packages (from stack-data->ipython>=1.0->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in /anaconda3/envs/info2950/lib/python3.10/site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.2.2)
# Requirement already satisfied: executing in /anaconda3/envs/info2950/lib/python3.10/site-packages (from stack-data->ipython>=1.0->ipython-sql) (0.8.3)

# %%
#storing the .csv files as dataframes
county_crime_dataset = pd.read_csv('Index_Crimes_by_County_and_Agency__\
Beginning_1990.csv')
nypd_arrests_dataset = pd.read_csv('NYPD_Arrests_Data__Historic_.csv')

# %% [markdown]
# We converted the dates in the ARREST_DATE column to DateTime values so we could easily access the time of the arrests. Also, because the reports in county_crime_dataset are listed by year, we added a YEAR column to nypd_arrests_dataset to more easily compare statistics among the two datasets.

# %%
nypd_arrests_dataset['ARREST_DATE'] = pd.to_datetime(nypd_arrests_dataset['ARREST_DATE'], format='%m/%d/%Y')
nypd_arrests_dataset['YEAR'] = nypd_arrests_dataset['ARREST_DATE'].dt.year
nypd_arrests_dataset.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                             PD_DESC  KY_CD  \
# 0   236791704  2021-11-22  581.0                                 NaN    NaN
# 1   237354740  2021-12-04  153.0                              RAPE 3  104.0
# 2   236081433  2021-11-09  681.0          CHILD, ENDANGERING WELFARE  233.0
# 3    32311380  2007-06-18  511.0  CONTROLLED SUBSTANCE, POSSESSION 7  235.0
# 4   192799737  2019-01-26  177.0                        SEXUAL ABUSE  116.0
#
#          OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 0              NaN  PL 2225001          M           M               28
# 1             RAPE  PL 1302502          F           B               41
# 2       SEX CRIMES  PL 2601001          M           Q              113
# 3  DANGEROUS DRUGS  PL 2200300          M           Q               27
# 4       SEX CRIMES  PL 1306503          F           M               25
#
#    JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  X_COORD_CD  \
# 0                0.0     45-64        M           BLACK    997427.0
# 1                0.0     25-44        M  WHITE HISPANIC   1013232.0
# 2                0.0     25-44        M           BLACK   1046367.0
# 3                1.0     18-24        M           BLACK         NaN
# 4                0.0     45-64        M           BLACK   1000555.0
#
#    Y_COORD_CD   Latitude  Longitude  \
# 0    230378.0  40.799009 -73.952409
# 1    236725.0  40.816392 -73.895296
# 2    186986.0  40.679700 -73.776047
# 3         NaN        NaN        NaN
# 4    230994.0  40.800694 -73.941109
#
#                                          Lon_Lat  YEAR
# 0  POINT (-73.95240854099995 40.799008797000056)  2021
# 1  POINT (-73.89529641399997 40.816391847000034)  2021
# 2   POINT (-73.77604736799998 40.67970040800003)  2021
# 3                                            NaN  2007
# 4  POINT (-73.94110928599997 40.800694331000045)  2019

# %% [markdown]
# Since our datasets covered different time periods, we wanted to make our datasets start and end at the same time.

# %%
county_2008 = county_crime_dataset[(county_crime_dataset \
['Year'] >= 2008) & (county_crime_dataset \
['Year'] <= 2021)]
county_crime_dataset.head()
county_crime_dataset.tail()
# Out:
#       County                     Agency  Year  Months Reported  Index Total  \
# 21818  Yates  Yates County State Police  2017             12.0         22.0
# 21819  Yates  Yates County State Police  2018             12.0         35.0
# 21820  Yates  Yates County State Police  2019             12.0         20.0
# 21821  Yates  Yates County State Police  2020             12.0         26.0
# 21822  Yates  Yates County State Police  2021             12.0         12.0
#
#        Violent Total  Murder  Rape  Robbery  Aggravated Assault  \
# 21818            6.0     0.0   3.0      0.0                 3.0
# 21819            3.0     0.0   3.0      0.0                 0.0
# 21820            6.0     0.0   5.0      0.0                 1.0
# 21821            3.0     0.0   2.0      0.0                 1.0
# 21822            3.0     0.0   3.0      0.0                 0.0
#
#        Property Total  Burglary  Larceny  Motor Vehicle Theft  \
# 21818            16.0       1.0     15.0                  0.0
# 21819            32.0       4.0     27.0                  1.0
# 21820            14.0       3.0     11.0                  0.0
# 21821            23.0       3.0     20.0                  0.0
# 21822             9.0       0.0      7.0                  2.0
#
#                   Region
# 21818  Non-New York City
# 21819  Non-New York City
# 21820  Non-New York City
# 21821  Non-New York City
# 21822  Non-New York City

# %%
nypd_arrests_2008 = nypd_arrests_dataset[(nypd_arrests_dataset \
['YEAR'] >= 2008) & (nypd_arrests_dataset \
['YEAR'] <= 2021)]
nypd_arrests_2008.head()
nypd_arrests_2008.tail()
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD                             PD_DESC  \
# 4801632    37566445  2008-01-08  567.0         MARIJUANA, POSSESSION 4 & 5
# 4801633    37565060  2008-01-08  511.0  CONTROLLED SUBSTANCE, POSSESSION 7
# 4801638    37543923  2008-01-07  205.0                TRESPASS 2, CRIMINAL
# 4801644    37640214  2008-01-11  478.0     THEFT OF SERVICES, UNCLASSIFIED
# 4801646    37688843  2008-01-14  905.0         INTOXICATED DRIVING,ALCOHOL
#
#          KY_CD                        OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 4801632  235.0                  DANGEROUS DRUGS  PL 2211001          M
# 4801633  235.0                  DANGEROUS DRUGS  PL 2200300          M
# 4801638  352.0                CRIMINAL TRESPASS  PL 1401500          M
# 4801644  343.0  OTHER OFFENSES RELATED TO THEFT  PL 1651503          M
# 4801646  347.0   INTOXICATED & IMPAIRED DRIVING  VTL11920M2          M
#
#         ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# 4801632           Q              114                0.0     25-44        M
# 4801633           B               41                0.0     45-64        M
# 4801638           B               42                0.0       <18        M
# 4801644           K               73                0.0       <18        M
# 4801646           Q              109                0.0     18-24        M
#
#                         PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  \
# 4801632                     WHITE   1006898.0    220358.0  40.771487
# 4801633            WHITE HISPANIC   1015927.0    236094.0  40.814651
# 4801638                     BLACK   1016142.0    243637.0  40.835353
# 4801644                     BLACK   1005571.0    181640.0  40.665219
# 4801646  ASIAN / PACIFIC ISLANDER   1030489.0    214264.0  40.754669
#
#          Longitude                                        Lon_Lat  YEAR
# 4801632 -73.918235  POINT (-73.91823481899996 40.771487379000064)  2008
# 4801633 -73.885563   POINT (-73.88556301199996 40.81465067700003)  2008
# 4801638 -73.884750   POINT (-73.88475043899997 40.83535328100004)  2008
# 4801644 -73.923148   POINT (-73.92314834999998 40.66521910700004)  2008
# 4801646 -73.833106   POINT (-73.83310572199997 40.75466902800008)  2008

# %% [markdown]
# We dropped the columns that did not directly relate to our research questions. For example, many of the columns concerning internal/legal codes were dropped from the nypd_arrests dataset.

# %%
county_drop_cols = ['Months Reported']
county_crime = county_2008.drop(county_drop_cols, axis = 1)
nypd_arrests_drop_cols = ['ARREST_KEY','PD_CD', 'PD_DESC', 'KY_CD', 'LAW_CODE', 'LAW_CAT_CD', 'ARREST_PRECINCT', 'JURISDICTION_CODE']
nypd_arrests = nypd_arrests_2008.drop(nypd_arrests_drop_cols, axis = 1)

# %%
county_crime.to_csv('county_crime.csv')
nypd_arrests.to_csv('nypd_arrests.csv')
